# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/rainfall in india 1901-2015.csv")#reading csv file

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data.head()#display top 5 rows default
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.groupby(["SUBDIVISION"]).count()#count the subdivision
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data.isna().sum()#duplicate values  are displayed
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1=data.loc[(data.YEAR<=2022)]#getting data greater than 2022

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data1.tail(60)#bottom below 60 rows
# Out:
#       SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 4056  LAKSHADWEEP  1956   13.6   27.7    1.3   40.8  269.5  356.1  109.8
# 4057  LAKSHADWEEP  1957    0.9   11.4   34.6   23.7  195.6  309.9  129.1
# 4058  LAKSHADWEEP  1958    0.2    1.6    0.0    8.0  116.0  269.4   84.5
# 4059  LAKSHADWEEP  1959   15.0    0.0    8.0   51.6  320.5  337.7  205.8
# 4060  LAKSHADWEEP  1960   29.6   40.0    3.3   85.4  497.1  176.8  257.3
# 4061  LAKSHADWEEP  1961   60.3   47.4    0.0   31.3  421.1  593.2  297.3
# 4062  LAKSHADWEEP  1962   11.1    0.0    0.0   81.5  331.2  149.3  204.5
# 4063  LAKSHADWEEP  1963  126.7  112.9    6.5   72.6  204.6  233.0  367.0
# 4064  LAKSHADWEEP  1964    2.5    3.5    5.2   40.4   64.2  376.1  407.0
# 4065  LAKSHADWEEP  1965    0.2    7.3    8.3   35.0  162.5  200.6  164.2
# 4066  LAKSHADWEEP  1966   21.3    0.2    6.2    4.4   34.9  376.7  421.9
# 4067  LAKSHADWEEP  1967    7.8    2.7    0.0    0.0  148.3  301.2  380.1
# ...

# %%
data2=data1.drop(["ANNUAL","Jan-Feb","Mar-May","Jun-Sep","Oct-Dec"],axis=1)#delete the columns

# %%
data2
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data2['SUBDIVISION'].unique()#unique subdivision names can be printed in array
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data2=data2.loc[(data2.SUBDIVISION=="ARUNACHAL PRADESH")]#only arunachal data can be printed

# %%
data2
# Out:
#            SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..                 ...   ...   ...    ...    ...    ...    ...     ...
# 202  ARUNACHAL PRADESH  2011  40.0   51.3  174.5  240.8  219.6   288.4
# 203  ARUNACHAL PRADESH  2012  57.8   35.8  134.2  403.4  187.4   645.8
# 204  ARUNACHAL PRADESH  2013  18.5   40.5  115.1  175.1  335.8   290.0
# 205  ARUNACHAL PRADESH  2014  19.0  101.9   80.3   86.7  299.0   415.8
# 206  ARUNACHAL PRADESH  2015  30.8   47.5   97.5  287.1  238.9   637.9
#
#         JUL    AUG    SEP    OCT   NOV   DEC
# 110     NaN  629.7  333.9    NaN   NaN   NaN
# ...

# %%
data3.isna().sum()#duplicate values  are displayed
# Out:
# SUBDIVISION    0
# YEAR           0
# ANNUAL RAIN    6
# dtype: int64

# %%
data2['ANNUAL RAIN']=data2.apply(lambda row:row.JAN + row.FEB+ row.MAR+ row.APR+ row.JUN+ row.JUL+ row.AUG+ row.SEP+ row.OCT+ row.NOV+ row.DEC,axis=1)

# %%
data2.head(10)
# Out:
#            SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# 115  ARUNACHAL PRADESH  1921  78.9   54.3  180.3  358.0  598.0  1233.2
# 116  ARUNACHAL PRADESH  1922  50.7   59.4  170.4  299.5  350.5  1109.3
# 117  ARUNACHAL PRADESH  1923   9.4  160.8   34.0  240.9  445.4   408.6
# 118  ARUNACHAL PRADESH  1924  85.7   45.1   74.1  162.4  515.7  1165.0
# 119  ARUNACHAL PRADESH  1925  80.6  114.0  143.3  223.0  587.2   611.6
#
#         JUL    AUG     SEP    OCT   NOV   DEC  ANNUAL RAIN
# 110     NaN  629.7   333.9    NaN   NaN   NaN          NaN
# 111   909.1  628.4   411.5  199.3  63.5   0.0          NaN
# ...

# %%
data3=data2.drop(["SUBDIVISION"],axis=1)#delete a column

# %%
data3
# Out:
#      YEAR   JAN    FEB    MAR    APR    MAY     JUN     JUL    AUG    SEP  \
# 110  1916  48.1   69.8   71.1  316.1  424.6  1124.9     NaN  629.7  333.9
# 111  1917  21.4  164.5    NaN  269.6  107.9   823.8   909.1  628.4  411.5
# 112  1918  10.4   11.0  191.2  144.6  861.1  1609.9  1303.0  692.6  515.8
# 113  1919  34.5   67.8   28.5  256.9  420.6   973.6   999.0  286.7  628.7
# 114  1920  14.0  196.3  605.6  364.7  173.6   840.6   535.4  896.5  376.7
# ..    ...   ...    ...    ...    ...    ...     ...     ...    ...    ...
# 202  2011  40.0   51.3  174.5  240.8  219.6   288.4   531.4  277.6  286.7
# 203  2012  57.8   35.8  134.2  403.4  187.4   645.8   638.9  316.0  724.9
# 204  2013  18.5   40.5  115.1  175.1  335.8   290.0   329.6  230.2  316.1
# 205  2014  19.0  101.9   80.3   86.7  299.0   415.8   392.4  599.6  343.0
# 206  2015  30.8   47.5   97.5  287.1  238.9   637.9   329.3  595.5  374.2
#
#        OCT   NOV   DEC  ANNUAL RAIN
# 110    NaN   NaN   NaN          NaN
# ...

# %%
cor_mat=data3.corr()#correlation
cor_mat
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000 -0.176300 -0.213918 -0.157302 -0.253946 -0.401934
# JAN         -0.176300  1.000000  0.083391  0.099054  0.256921  0.217524
# FEB         -0.213918  0.083391  1.000000  0.321564  0.205643 -0.027577
# MAR         -0.157302  0.099054  0.321564  1.000000  0.307354  0.023099
# APR         -0.253946  0.256921  0.205643  0.307354  1.000000  0.097526
# MAY         -0.401934  0.217524 -0.027577  0.023099  0.097526  1.000000
# JUN         -0.626889  0.208187  0.111802  0.111475  0.290472  0.398268
# JUL         -0.494607  0.071617  0.140842  0.047547  0.238319  0.510852
# AUG         -0.394066  0.193102  0.063751  0.058362  0.132668  0.367445
# SEP         -0.396480  0.189419  0.154883  0.054761  0.198362  0.246939
# OCT         -0.325208  0.169379 -0.024632 -0.137731  0.054994  0.141720
# NOV         -0.096053  0.162395  0.159914 -0.048569  0.295455  0.040734
# ...

# %%
import seaborn as reddy#correlation by using graph
reddy.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidth=.5,cmap='bwr')
# Out:
# <AxesSubplot:>

# %%
data3['nem']=data2.apply(lambda row:row.OCT+ row.NOV+ row.DEC,axis=1)#adding rows

# %%
data3
# Out:
#      YEAR   JAN    FEB    MAR    APR    MAY     JUN     JUL    AUG    SEP  \
# 110  1916  48.1   69.8   71.1  316.1  424.6  1124.9     NaN  629.7  333.9
# 111  1917  21.4  164.5    NaN  269.6  107.9   823.8   909.1  628.4  411.5
# 112  1918  10.4   11.0  191.2  144.6  861.1  1609.9  1303.0  692.6  515.8
# 113  1919  34.5   67.8   28.5  256.9  420.6   973.6   999.0  286.7  628.7
# 114  1920  14.0  196.3  605.6  364.7  173.6   840.6   535.4  896.5  376.7
# ..    ...   ...    ...    ...    ...    ...     ...     ...    ...    ...
# 202  2011  40.0   51.3  174.5  240.8  219.6   288.4   531.4  277.6  286.7
# 203  2012  57.8   35.8  134.2  403.4  187.4   645.8   638.9  316.0  724.9
# 204  2013  18.5   40.5  115.1  175.1  335.8   290.0   329.6  230.2  316.1
# 205  2014  19.0  101.9   80.3   86.7  299.0   415.8   392.4  599.6  343.0
# 206  2015  30.8   47.5   97.5  287.1  238.9   637.9   329.3  595.5  374.2
#
#        OCT   NOV   DEC  ANNUAL RAIN    nem
# ...

# %%
data3['swm']=data2.apply(lambda row: row.JUN+ row.JUL+ row.AUG+ row.SEP,axis=1)#adding columns

# %%
data3
# Out:
#      YEAR   JAN    FEB    MAR    APR    MAY     JUN     JUL    AUG    SEP  \
# 110  1916  48.1   69.8   71.1  316.1  424.6  1124.9     NaN  629.7  333.9
# 111  1917  21.4  164.5    NaN  269.6  107.9   823.8   909.1  628.4  411.5
# 112  1918  10.4   11.0  191.2  144.6  861.1  1609.9  1303.0  692.6  515.8
# 113  1919  34.5   67.8   28.5  256.9  420.6   973.6   999.0  286.7  628.7
# 114  1920  14.0  196.3  605.6  364.7  173.6   840.6   535.4  896.5  376.7
# ..    ...   ...    ...    ...    ...    ...     ...     ...    ...    ...
# 202  2011  40.0   51.3  174.5  240.8  219.6   288.4   531.4  277.6  286.7
# 203  2012  57.8   35.8  134.2  403.4  187.4   645.8   638.9  316.0  724.9
# 204  2013  18.5   40.5  115.1  175.1  335.8   290.0   329.6  230.2  316.1
# 205  2014  19.0  101.9   80.3   86.7  299.0   415.8   392.4  599.6  343.0
# 206  2015  30.8   47.5   97.5  287.1  238.9   637.9   329.3  595.5  374.2
#
#        OCT   NOV   DEC  ANNUAL RAIN    nem     swm
# ...

# %%
data3=data3.drop(["JAN","FEB","MAR","APR","MAY","JUN","JUL","AUG","SEP","OCT","NOV","DEC"],axis=1)#drop column

# %%
data3
# Out:
#      YEAR  ANNUAL RAIN    nem     swm
# 110  1916          NaN    NaN     NaN
# 111  1917          NaN  262.8  2772.8
# 112  1918       4625.2  146.7  4121.3
# 113  1919       4273.3  997.6  2888.0
# 114  1920       3933.1  103.3  2649.2
# ..    ...          ...    ...     ...
# 202  2011       1974.0   83.3  1384.1
# 203  2012       3253.1  296.3  2325.6
# 204  2013       1707.1  192.0  1165.9
# 205  2014       2104.1   65.4  1750.8
# 206  2015       2528.6  128.8  1936.9
#
# [97 rows x 4 columns]

# %%
data4=data3.drop(["YEAR"],axis=1)#drop column

# %%
data4
# Out:
#      ANNUAL RAIN    nem     swm
# 110          NaN    NaN     NaN
# 111          NaN  262.8  2772.8
# 112       4625.2  146.7  4121.3
# 113       4273.3  997.6  2888.0
# 114       3933.1  103.3  2649.2
# ..           ...    ...     ...
# 202       1974.0   83.3  1384.1
# 203       3253.1  296.3  2325.6
# 204       1707.1  192.0  1165.9
# 205       2104.1   65.4  1750.8
# 206       2528.6  128.8  1936.9
#
# [97 rows x 3 columns]

# %%
cor_mat=data4.corr()#correlation
cor_mat
# Out:
#              ANNUAL RAIN       nem       swm
# ANNUAL RAIN     1.000000  0.451615  0.970880
# nem             0.451615  1.000000  0.320171
# swm             0.970880  0.320171  1.000000

# %%
import seaborn as reddy#correlation by using graph
reddy.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidth=.5,cmap='bwr')
# Out:
# <AxesSubplot:>
